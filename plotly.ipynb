# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
fig=px.line(x=[7,8,9],y=[12,25,40])
print(fig)
# Out:
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array([7, 8, 9], dtype=int64),
#               'xaxis': 'x',
#               'y': array([12, 25, 40], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %%
fig.show()

# %%
#load the dataset
iris=px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# ...

# %%
#Retrieving the dataset:
iris=px.data.iris()
fig1=px.line(iris,x="species",y="petal_width")
fig1.show()

# %%
fig3=px.bar(iris,x="sepal_width",y="sepal_length")
fig3.show()

# %%
fig3=px.histogram(iris,x="sepal_width",y="sepal_length")
fig3.show()

# %%
fig3=px.scatter(iris,x="species",y="petal_width")
fig3.show()

# %%
fig3=px.scatter(iris,x="species",y="petal_width",size="petal_length",color="species")
fig3.show()

# %%
tips=px.data.tips()
fig5=px.pie(tips,values="total_bill",names="day")
fig5.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips=px.data.tips()
fig5=px.pie(tips,values="total_bill",names="size") -->values=total bill,names will be clled all the properties.
fig5.show()

# %%
tips=px.data.tips()
fig5=px.box(tips,x="day",y="total_bill")
fig5.show()

# %%
tips=px.data.tips()
fig5=px.box(tips,x="time",y="total_bill")
fig5.show()

# %%
tips=px.data.tips()
fig5=px.box(tips,x="size",y="total_bill")
fig5.show()

# %%
tips=px.data.tips()
fig5=px.violin(tips,x="smoker",y="total_bill")
fig5.show()

# %%
tips=px.data.tips()
fig5=px.violin(tips,x="tip",y="total_bill")
fig5.show()

# %%
tips=px.data.tips()
fig5=px.violin(tips,x="day",y="total_bill")
fig5.show()

# %%
tips=px.data.tips()
fig5=px.box(tips,x="sex",y="total_bill")
fig5.show()

# %%
fig7=px.line_3d(tips,x="sex",y="day",z="time",color="sex")
fig7.show()

# %% [markdown]
# # Package of structure of plotly:
#   There are three main modules in plotly.they are: *Plotly.Plotly *Plotly.Graph.Objects *Plotly.Tools

# %%
import pandas as pd
from sklearn.datasets import load_iris
from matplotlib import pyplot as plt

# %%
iris=load_iris()

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
tips=px.data.tips()
fig5=px.violin(tips,x="day",y="total_bill")
fig5.show()

# %%
tips=px.data.tips()
fig5=px.stripplot(tips,x="day",y="total_bill")
fig5.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[99], line 2
#       1 tips=px.data.tips()
# ----> 2 fig5=px.stripplot(tips,x="day",y="total_bill")
#       3 fig5.show()
#
# AttributeError: module 'plotly.express' has no attribute 'stripplot'

# %%
fig7=px.scatter_3d(tips,x="sex",y="day",z="time",color="sex")
fig7.show()

# %%
fig7=px.histogram(tips,x="sex",y="day",color="sex")
fig7.show()

# %% [markdown]
# # Gantt Charts - Generalized Activity Normalization Time table
#         this type of chart in which series of horizontal lines are present that show the amount of work done or
# production completed in given period of time in relation to amount planned for those projects.

# %%
 import plotly.figure_factory as ff
#data to be plotted
df=[dict(Task="A",Start='2020-01-01',Finish='2020-02-02'),
    dict(Task="Job B",Start='2020-03-01',Finish='2020-11-11'),
    dict(Task="Job C",Start='2020-08-06',Finish='2020-09-21')]
#creating the plot
fig=ff.create_gantt(df)
fig.show()

# %%
import plotly.graph_objects as go
import numpy as np
import plotly.figure_factory as ff
#creating the x,y value that will
#change the values of z as a function
feature_x = np.arange(0,50,2)
feature_y = np.arange(0,50,3)
#creating 2-D grid of  features
[x,y] = np.meshgrid(feature_x, feature_y)
z = np.cos(x/2) + np.sin(y/4)
#plotting the figure
fig3 = go.Figure(data = go.contour(x = feature_x, y = feature_y, z = z))
fig3.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[141], line 12
#      10 z = np.cos(x/2) + np.sin(y/4)
#      11 #plotting the figure
# ---> 12 fig3 = go.Figure(data = go.contour(x = feature_x, y = feature_y, z = z))
#      13 fig3.show()
#
# TypeError: 'module' object is not callable

# %% [markdown]
# # 3D Line Plots

# %%
import plotly.express as px
df=px.data.tips()
fig=px.line_3d(df,x="sex",y="day",z="time",color="sex")
fig.show()

# %%
import plotly.express as px
df=px.data.iris()
fig=px.scatter_3d(df,x='sepal_width',y='sepal_length',z='petal_width',color='species')
fig.show()

# %%
import plotly.graph_objects as go
import numpy as np
x=np.outer(np.linspace(-2,2,30),np.ones(30))
y=x.copy().T
z=np.cos(x**2+y**2)
fig=go.figure(data=[go.surface(x=x,y=y,z=z)])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[148], line 6
#       4 y=x.copy().T
#       5 z=np.cos(x**2+y**2)
# ----> 6 fig=go.figure(data=[go.surface(x=x,y=y,z=z)])
#       7 fig.show()
#
# File ~\anaconda3\Lib\site-packages\plotly\graph_objects\__init__.py:299, in __getattr__(import_name)
#     295         from ..missing_ipywidgets import FigureWidget
#     297         return FigureWidget
# --> 299 return orig_getattr(import_name)
#
# File ~\anaconda3\Lib\site-packages\_plotly_utils\importers.py:39, in relative_import.<locals>.__getattr__(import_name)
#      36     class_module = importlib.import_module(rel_module, parent_name)
#      37     return getattr(class_module, class_name)
# ---> 39 raise AttributeError(
#      40     "module {__name__!r} has no attribute {name!r}".format(
#      41         name=import_name, __name__=parent_name
#      42     )
# ...
