# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
l=[12,13,14,15]
s1=pd.Series(l)
print(s1)
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# dtype: int64

# %%
# 2 -- read salaries.csv as a dataframe called sal.
import pandas as pd
from pandas import Series,DataFrame
a=pd.read_csv("salaries.csv")
a
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# 3
a.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
#4 
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#5
import pandas as pd
from pandas import Series,DataFrame

average_base_pay=a['BasePay'].mean()
print(average_base_pay)
# Out:
# 66325.4488404877

# %%
# 6 -- what is the highest amount of overtimepay in the dataset?
a['OvertimePay'].max()
# Out:
# 245131.88

# %%
# 7 -- what is the title of joseph driscoll?notes:use all caps,otherwise you may get an answer that doesnot match up
                                                                                       #(there is also a lowercase joseph driscoll)
a[a['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
# 8 -- howmuch does joseph driscoll make including benefits
a[a['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
# 9 -- what is the name of highest paid person including benefits?
a[a['TotalPayBenefits'] == a['TotalPayBenefits'].max()]   #position of serialnum and identify the name
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
a[a['TotalPayBenefits'] == a['TotalPayBenefits'].max()]['JobTitle']
# Out:
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# Name: JobTitle, dtype: object

# %%
#how much does joseph dirscoll make(including benefits)
a[a['TotalPayBenefits'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# Series([], Name: TotalPayBenefits, dtype: float64)

# %%
a[a['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
# 10-- what is the name of lowest paid person (including benefits)
                                                           #lowest amount will be mentioned.
a[a['TotalPayBenefits'] == a['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
# 11 -- what was the average (mean)basepay of all employees per year(2011-2014)?
a.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
#12-- how many uniqune job titile are there?
a['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
a['JobTitle'].nunique()  #null value also included
# Out:
# 2159

# %%
#13 -- what are the top 5 most common jobs?
a['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
#14 -- how many job title were represented by one person in 2013? e.g. job titles with only one occurencs in 2013?
(a[a['Year']==2013]['JobTitle'].value_counts()==1).sum()
# Out:
# 202

# %%
#15 --how many people have in the word chief in their job title? (this is pretty tricky)
import pandas as pd
from pandas import Series,DataFrame
a=pd.read_csv("salaries.csv")
a
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
chief_count = a['JobTitle'].str.contains('Chief',case=True).sum()
#print the result
print(f'count the number of people in the word chief in their job title:{chief_count}')
# Out:
# count the number of people in the word chief in their job title:423

# %%
# bonuss is there a correlation between length of the job title string and salary?
a['Job']=a['JobTitle'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # bonuss is there a correlation between length of the job title string and salary?
# ----> 2 a['Job']=a['JobTitle'].apply(len)
#
# NameError: name 'a' is not defined

# %%
a[['Job','TotalPayBenefits']].corr()
# Out:
#                        Job  TotalPayBenefits
# Job               1.000000         -0.036878
# TotalPayBenefits -0.036878          1.000000
