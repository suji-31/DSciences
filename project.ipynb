# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("Rotten_Tomatoes_Movies3.xls")
df
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16633                                          Zoot Suit
# 16634                                           Zootopia
# 16635                                    Zorba the Greek
# 16636                                               Zulu
# 16637                                          Zulu Dawn
#
#                                               movie_info  \
# 0      A teenager discovers he's the descendant of a ...
# 1      Kate has a lot on her mind. There's the ethics...
# 2      Blake Edwards' 10 stars Dudley Moore as George...
# ...

# %%
df[['genre', 'directors']]
# Out:
#                                                    genre  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 16633                   Drama, Musical & Performing Arts
# 16634              Action & Adventure, Animation, Comedy
# 16635  Action & Adventure, Art House & International,...
# 16636                                    Classics, Drama
# 16637  Action & Adventure, Art House & International,...
#
#                                   directors
# 0                            Chris Columbus
# 1                         Nicole Holofcener
# 2                             Blake Edwards
# 3                              Sidney Lumet
# 4                         Richard Fleischer
# ...

# %%
df.loc[0] #row values
# Out:
# movie_title           Percy Jackson & the Olympians: The Lightning T...
# movie_info            A teenager discovers he's the descendant of a ...
# critics_consensus     Though it may seem like just another Harry Pot...
# rating                                                               PG
# genre                 Action & Adventure, Comedy, Drama, Science Fic...
# directors                                                Chris Columbus
# writers                                                    Craig Titley
# cast                  Logan Lerman, Brandon T. Jackson, Alexandra Da...
# in_theaters_date                                    2010-02-12 00:00:00
# on_streaming_date                                   2010-06-29 00:00:00
# runtime_in_minutes                                                 83.0
# studio_name                                            20th Century Fox
# tomatometer_status                                               Rotten
# ...

# %%
df.drop('movie_info',axis=1)
# Out:
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16633                                          Zoot Suit
# 16634                                           Zootopia
# 16635                                    Zorba the Greek
# 16636                                               Zulu
# 16637                                          Zulu Dawn
#
#                                        critics_consensus rating  \
# 0      Though it may seem like just another Harry Pot...     PG
# 1      Nicole Holofcener's newest might seem slight i...      R
# 2                                                    NaN      R
# ...

# %%
df.head()
# Out:
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus rating  \
# 0  Though it may seem like just another Harry Pot...     PG
# 1  Nicole Holofcener's newest might seem slight i...      R
# 2                                                NaN      R
# 3  Sidney Lumet's feature debut is a superbly wri...     NR
# ...

# %%
df.tail()
# Out:
#            movie_title                                         movie_info  \
# 16633        Zoot Suit  Based on a 1940s Los Angeles murder trial, thi...
# 16634         Zootopia  The modern mammal metropolis of Zootopia is a ...
# 16635  Zorba the Greek  If ever there was a role that Anthony Quinn wa...
# 16636             Zulu  Filmed on a grand scale, Zulu is a rousing rec...
# 16637        Zulu Dawn  A prequel to Zulu, Zulu Dawn depicts the event...
#
#                                        critics_consensus rating  \
# 16633                                                NaN      R
# 16634  The brilliantly well-rounded Zootopia offers a...     PG
# 16635                                                NaN     NR
# 16636                                                NaN     PG
# 16637                                                NaN     PG
#
#                                                    genre  \
# 16633                   Drama, Musical & Performing Arts
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16638 entries, 0 to 16637
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_title         16638 non-null  object
#  1   movie_info          16614 non-null  object
#  2   critics_consensus   8309 non-null   object
#  3   rating              16638 non-null  object
#  4   genre               16621 non-null  object
#  5   directors           16524 non-null  object
#  6   writers             15289 non-null  object
#  7   cast                16354 non-null  object
#  8   in_theaters_date    15823 non-null  datetime64[ns]
#  9   on_streaming_date   16636 non-null  datetime64[ns]
#  10  runtime_in_minutes  16483 non-null  float64
#  11  studio_name         16222 non-null  object
#  12  tomatometer_status  16638 non-null  object
#  13  tomatometer_rating  16638 non-null  int64
#  14  tomatometer_count   16638 non-null  int64
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=16638, step=1)

# %%
df.columns
# Out:
# Index(['movie_title', 'movie_info', 'critics_consensus', 'rating', 'genre',
#        'directors', 'writers', 'cast', 'in_theaters_date', 'on_streaming_date',
#        'runtime_in_minutes', 'studio_name', 'tomatometer_status',
#        'tomatometer_rating', 'tomatometer_count', 'audience_rating'],
#       dtype='object')

# %%
# changed the columns names:
new={'movie_title':'MOVIE_TITLE','critics_consensus':'CRITICUS_CONSENSUS','directors':'DIRECTORS','cast':'CAST',
     'on_streaming_date':'ON_STREAMING_DATE','studio_name':'STUDIO_NAME','tomatometer_rating':'TOMATOMETER_RATING',
     'audience_rating':'AUDIENCE_RATING'}
new
# Out:
# {'movie_title': 'MOVIE_TITLE',
#  'critics_consensus': 'CRITICUS_CONSENSUS',
#  'directors': 'DIRECTORS',
#  'cast': 'CAST',
#  'on_streaming_date': 'ON_STREAMING_DATE',
#  'studio_name': 'STUDIO_NAME',
#  'tomatometer_rating': 'TOMATOMETER_RATING',
#  'audience_rating': 'AUDIENCE_RATING'}

# %%
df.rename(columns=new,inplace=True)
df.head()
# Out:
#                                          MOVIE_TITLE  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                   CRITICUS_CONSENSUS rating  \
# 0  Though it may seem like just another Harry Pot...     PG
# 1  Nicole Holofcener's newest might seem slight i...      R
# 2                                                NaN      R
# 3  Sidney Lumet's feature debut is a superbly wri...     NR
# ...

# %%
df.iloc[1002]
# Out:
# MOVIE_TITLE                                                     Top Dog
# movie_info            In this action comedy, renegade cop Jake Wilde...
# CRITICUS_CONSENSUS                                                  NaN
# rating                                                            PG-13
# genre                                        Action & Adventure, Comedy
# DIRECTORS                                                  Aaron Norris
# writers                                                             NaN
# CAST                  Chuck Norris, Clyde Kusatsu, Michele Lamar Ric...
# in_theaters_date                                    1994-06-01 00:00:00
# ON_STREAMING_DATE                                   2001-02-20 00:00:00
# runtime_in_minutes                                                 93.0
# STUDIO_NAME                                          Live Entertainment
# tomatometer_status                                               Rotten
# ...

# %%
df.loc[221]
# Out:
# MOVIE_TITLE                                                     Endgame
# movie_info            The African National Congress (ANC) wages an a...
# CRITICUS_CONSENSUS                                                  NaN
# rating                                                            PG-13
# genre                                         Drama, Mystery & Suspense
# DIRECTORS                                                   Pete Travis
# writers                                                     Paula Milne
# CAST                  William Hurt, Chiwetel Ejiofor, Jonny Lee Mill...
# in_theaters_date                                    2009-11-06 00:00:00
# ON_STREAMING_DATE                                   2010-02-09 00:00:00
# runtime_in_minutes                                                109.0
# STUDIO_NAME                                              Monterey Media
# tomatometer_status                                                Fresh
# ...

# %%
df.loc[212]
# Out:
# MOVIE_TITLE                                              The Stepfather
# movie_info            A seemingly normal man wants the perfect famil...
# CRITICUS_CONSENSUS    This tepid remake of the 1987 cult classic lac...
# rating                                                            PG-13
# genre                                        Horror, Mystery & Suspense
# DIRECTORS                                              Nelson McCormick
# writers                                Donald E. Westlake, J.S. Cardone
# CAST                  Dylan Walsh, Penn Badgley, Sela Ward, Amber He...
# in_theaters_date                                    2009-10-16 00:00:00
# ON_STREAMING_DATE                                   2010-02-09 00:00:00
# runtime_in_minutes                                                103.0
# STUDIO_NAME                                                 Screen Gems
# tomatometer_status                                               Rotten
# ...

# %%
df.iloc[1000]
# Out:
# MOVIE_TITLE                                              The Wild Bunch
# movie_info            Sam Peckinpah's controversial revisionist West...
# CRITICUS_CONSENSUS    The Wild Bunch is Sam Peckinpah's shocking, vi...
# rating                                                                R
# genre                                Action & Adventure, Drama, Western
# DIRECTORS                                                 Sam Peckinpah
# writers                      Sam Peckinpah, Walon Green, Roy N. Sickner
# CAST                  William Holden, Ernest Borgnine, Robert Ryan, ...
# in_theaters_date                                    1969-06-18 00:00:00
# ON_STREAMING_DATE                                   1997-08-27 00:00:00
# runtime_in_minutes                                                145.0
# STUDIO_NAME                                       Warner Bros. Pictures
# tomatometer_status                                      Certified Fresh
# ...

# %%
df[['MOVIE_TITLE','CRITICUS_CONSENSUS','writers','CAST']]
# Out:
#                                              MOVIE_TITLE  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16633                                          Zoot Suit
# 16634                                           Zootopia
# 16635                                    Zorba the Greek
# 16636                                               Zulu
# 16637                                          Zulu Dawn
#
#                                       CRITICUS_CONSENSUS  \
# 0      Though it may seem like just another Harry Pot...
# 1      Nicole Holofcener's newest might seem slight i...
# 2                                                    NaN
# ...

# %%
df['TOMATOMETER_RATING'].min()
# Out:
# 0

# %%
df['TOMATOMETER_RATING'].max()
# Out:
# 100

# %%
df['AUDIENCE_RATING'].mean()
# Out:
# 60.47082875625534

# %%
df['tomatometer_count'].min()
# Out:
# 5

# %%
df.iloc[4292]
# Out:
# MOVIE_TITLE                                   The Children of Huang Shi
# movie_info            Inspired by true events, the film tells the st...
# CRITICUS_CONSENSUS    This beautifully photographed but dramatically...
# rating                                                                R
# genre                                  Art House & International, Drama
# DIRECTORS                                            Roger Spottiswoode
# writers                                   James MacManus, Jane Hawksley
# CAST                  Jonathan Rhys Meyers, Radha Mitchell, Yun-Fat ...
# in_theaters_date                                    2008-05-23 00:00:00
# ON_STREAMING_DATE                                   2009-01-20 00:00:00
# runtime_in_minutes                                                125.0
# STUDIO_NAME                                      Sony Pictures Classics
# tomatometer_status                                               Rotten
# ...

# %%
#missing null values non not a number
df.isnull()
# Out:
#        MOVIE_TITLE  movie_info  CRITICUS_CONSENSUS  rating  genre  DIRECTORS  \
# 0            False       False               False   False  False      False
# 1            False       False               False   False  False      False
# 2            False       False                True   False  False      False
# 3            False       False               False   False  False      False
# 4            False       False               False   False  False      False
# ...            ...         ...                 ...     ...    ...        ...
# 16633        False       False                True   False  False      False
# 16634        False       False               False   False  False      False
# 16635        False       False                True   False  False       True
# 16636        False       False                True   False  False      False
# 16637        False       False                True   False  False      False
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#                      MOVIE_TITLE  \
# 2                             10
# 7                   3:10 to Yuma
# 8      Charly (A Heartbeat Away)
# 9                Abraham Lincoln
# 10                    Dark Water
# ...                          ...
# 16628                        Zoo
# 16633                  Zoot Suit
# 16635            Zorba the Greek
# 16636                       Zulu
# 16637                  Zulu Dawn
#
#                                               movie_info CRITICUS_CONSENSUS  \
# 2      Blake Edwards' 10 stars Dudley Moore as George...                NaN
# 7      Desperate for money, frontier rancher Van Hefl...                NaN
# 8      Sam Roberts thinks he has all the answers: the...                NaN
# 9      To date, this D.W. Griffith epic is the only t...                NaN
# 10     Following up on his horror smash hits Ringu an...                NaN
# ...                                                  ...                ...
# ...

# %%
#missing value of the colmun
df.dropna()
# Out:
#                                              MOVIE_TITLE  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# 5                                            10,000 B.C.
# ...                                                  ...
# 16629                                          Zookeeper
# 16630                                          Zoolander
# 16631                                        Zoolander 2
# 16632                                               Zoom
# 16634                                           Zootopia
#
#                                               movie_info  \
# 0      A teenager discovers he's the descendant of a ...
# 1      Kate has a lot on her mind. There's the ethics...
# 3      A Puerto Rican youth is on trial for murder, a...
# ...

# %%
df.replace({'tomatometer_status':{'Certified Fresh':'CS','Rotten':'RT'}})
# Out:
#                                              MOVIE_TITLE  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16633                                          Zoot Suit
# 16634                                           Zootopia
# 16635                                    Zorba the Greek
# 16636                                               Zulu
# 16637                                          Zulu Dawn
#
#                                               movie_info  \
# 0      A teenager discovers he's the descendant of a ...
# 1      Kate has a lot on her mind. There's the ethics...
# 2      Blake Edwards' 10 stars Dudley Moore as George...
# ...

# %%
#delete column:
del df['genre']
df.head()
# Out:
#                                          MOVIE_TITLE  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                   CRITICUS_CONSENSUS rating  \
# 0  Though it may seem like just another Harry Pot...     PG
# 1  Nicole Holofcener's newest might seem slight i...      R
# 2                                                NaN      R
# 3  Sidney Lumet's feature debut is a superbly wri...     NR
# ...

# %%
df.count()
# Out:
# MOVIE_TITLE           16638
# movie_info            16614
# CRITICUS_CONSENSUS     8309
# rating                16638
# DIRECTORS             16524
# writers               15289
# CAST                  16354
# in_theaters_date      15823
# ON_STREAMING_DATE     16636
# runtime_in_minutes    16483
# STUDIO_NAME           16222
# tomatometer_status    16638
# TOMATOMETER_RATING    16638
# tomatometer_count     16638
# AUDIENCE_RATING       16386
# dtype: int64

# %%
df.describe()
# Out:
#                     in_theaters_date              ON_STREAMING_DATE  \
# count                          15823                          16636
# mean   1999-10-24 22:10:52.973519488  2008-08-13 13:35:49.266650624
# min              1914-06-01 00:00:00            1935-06-06 00:00:00
# 25%              1993-03-29 00:00:00            2003-01-28 00:00:00
# 50%              2006-08-04 00:00:00            2008-04-08 00:00:00
# 75%              2013-06-28 00:00:00            2014-05-12 00:00:00
# max              2019-12-07 00:00:00            2019-11-01 00:00:00
# std                              NaN                            NaN
#
#        runtime_in_minutes  TOMATOMETER_RATING  tomatometer_count  \
# count        16483.000000        16638.000000       16638.000000
# mean           102.391494           60.466522          56.607104
# min              1.000000            0.000000           5.000000
# 25%             90.000000           38.000000          12.000000
# ...
