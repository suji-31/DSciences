# %% [markdown]
# # Titanic Datasets:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

titanic=pd.read_csv('tested.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
sns.set_style('darkgrid')
sns.barplot(x='Sex',y='Name',data=titanic,palette='plasma')
import numpy as np
sns.barplot(x='Sex',y='Name',data=titanic, palette='plasma',estimator=np.std)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4716\494853775.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sex',y='Name',data=titanic,palette='plasma')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4716\494853775.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sex',y='Name',data=titanic, palette='plasma',estimator=np.std)
# <Axes: xlabel='Sex', ylabel='Name'>

# %%
sns.stripplot(x='Age',y='Pclass',data=titanic,jitter=True,hue='Sex',dodge=True)
# Out:
# <Axes: xlabel='Age', ylabel='Pclass'>

# %%
sns.swarmplot(x='Sex',y='Age',data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(x='Sex',y='Age',data=titanic)
sns.swarmplot(x='Sex',y='Age',data=titanic,color='black')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.factorplot(x='Sex',y='Age',data=titanic,kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.factorplot(x='Sex',y='Age',data=titanic,kind='bar')
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
sns.set_style('whitegrid')
sns.distplot(titanic['Pclass'], kde = False, color='red', bins=30)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4716\1267450777.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['Pclass'], kde = False, color='red', bins=30)
# <Axes: xlabel='Pclass'>

# %%
sns.jointplot(x='Pclass',y='Sex',data=titanic)

# %%
sns.jointplot(x='Age',y='Pclass',data=titanic,kind='kde')

# %%
sns.set_style('whitegrid')
sns.lmplot(x='Age',y='Pclass',data=titanic)

# %%
sns.set_style('whitegrid')
sns.lmplot(x='Age',y='Pclass',data=titanic,hue='Sex',markers=['o','v'])

# %%
sns.set_style('whitegrid')
sns.lmplot(x='Age',y='Pclass',data=titanic,hue='Sex',markers=['o','v'],scatter_kws={'s':100},palette='plasma')

# %%
sns.lmplot(x='Age',y='Pclass',data=titanic,col='Sex',row='Sex',hue='Sex')

# %%
sns.lmplot(x='Age',y='Pclass',data=titanic,col='Embarked',row='Sex',hue='Sex')

# %%
sns.lmplot(x='Age',y='Pclass',data=titanic,col='Embarked',row='Sex',hue='Sex',aspect=0.6,palette='coolwarm')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(titanic.columns)
titanic=titanic.rename(columns={'old_name':'Fare'})
# Out:
# Index([0.17, 0.33, 0.75, 0.83, 0.92,  1.0,  2.0,  3.0,  5.0,  6.0,  7.0,  8.0,
#         9.0, 10.0, 11.5, 12.0, 13.0, 14.0, 14.5, 15.0, 16.0, 17.0, 18.0, 18.5,
#        19.0, 20.0, 21.0, 22.0, 22.5, 23.0, 24.0, 25.0, 26.0, 26.5, 27.0, 28.0,
#        28.5, 29.0, 30.0, 31.0, 32.0, 32.5, 33.0, 34.0, 34.5, 35.0, 36.0, 36.5,
#        37.0, 38.0, 38.5, 39.0, 40.0, 40.5, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0,
#        47.0, 48.0, 49.0, 50.0, 51.0, 53.0, 54.0, 55.0, 57.0, 58.0, 59.0, 60.0,
#        60.5, 61.0, 62.0, 63.0, 64.0, 67.0, 76.0],
#       dtype='float64', name='Age')
