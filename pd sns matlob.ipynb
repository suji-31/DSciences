# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
l=[23,45,80,54,68]
s=pd.Series(l)
print(s)
# Out:
# 0    23
# 1    45
# 2    80
# 3    54
# 4    68
# dtype: int64

# %%
a=np.array(l)
print(a)
print(a.dtype)
# Out:
# [23 45 80 54 68]
# int32

# %%
l=[45,60,55,85,50]
s3=Series(l,index=['A','B','C','D','E'])
print(s3)
# Out:
# A    45
# B    60
# C    55
# D    85
# E    50
# dtype: int64

# %%
print(s3[['B','D']])
# Out:
# B    60
# D    85
# dtype: int64

# %%
#creating series from dictionary
dic={"Name":"Suji","ID":2024,"Degree":"Data Sciences","Role":"Student"}
se=Series(dic)
print(se)
# Out:
# Name               Suji
# ID                 2024
# Degree    Data Sciences
# Role            Student
# dtype: object

# %%
print(dic["ID"])
print(se["Degree"])
# Out:
# 2024
# Data Sciences

# %%
s=np.array(["Suzi","Kanna","Suruthi","Tj","Kanmani"])
print(s)
print(s.dtype)
# Out:
# ['Suzi' 'Kanna' 'Suruthi' 'Tj' 'Kanmani']
# <U7

# %%
#to check the condition in Series Data
s3>=45
# Out:
# A    True
# B    True
# C    True
# D    True
# E    True
# dtype: bool

# %%
#To get the true condition values
s3[s3>=45]
# Out:
# A    45
# B    60
# C    55
# D    85
# E    50
# dtype: int64

# %%
l=[[1,2,3,4],[4,5,6,7]]
df=DataFrame(data=1,index=['r1','r2'],columns=['col1','col2','col3','col4'])
print(df)
# Out:
#     col1  col2  col3  col4
# r1     1     1     1     1
# r2     1     1     1     1

# %%
l=[[1,2,3,4],[4,5,6,7]]
df=DataFrame(l)
print(df)
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  4  5  6  7

# %%
#Find the missing values in tabular column
s=Series([np.nan,1,2,3,np.nan],index=['r1','r2','r3','r4','r5'])
s
# Out:
# r1    NaN
# r2    1.0
# r3    2.0
# r4    3.0
# r5    NaN
# dtype: float64

# %%
s.isnull()
# Out:
# r1     True
# r2    False
# r3    False
# r4    False
# r5     True
# dtype: bool

# %%
s.dropna()
# Out:
# r2    1.0
# r3    2.0
# r4    3.0
# dtype: float64

# %%
ar=np.random.randn(5,4)
ar
# Out:
# array([[ 0.11165302,  1.23482414, -0.60989889,  0.48575395],
#        [ 1.20147499, -0.4777607 ,  0.38587233, -1.06396487],
#        [-1.60104304, -0.17455588,  0.48131111, -0.03001811],
#        [ 1.02017198,  1.4447382 , -0.79364125, -0.07416587],
#        [ 0.16747218, -0.38181928, -1.16291363,  1.74891156]])

# %%
import pandas as pd
d=pd.read_csv('TARP.csv')
d
# Out:
#        Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0                 54           22              70    21                19.52
# 1                 12           20              40   104                19.49
# 2                 34           26              35    62                19.47
# 3                  7           44              44    93                19.54
# 4                 50           38              23    92                19.61
# ...              ...          ...             ...   ...                  ...
# 99995             74            3              29    83                  NaN
# 99996             58           10              46    82                  NaN
# 99997              4           35              39    17                  NaN
# 99998             83           36              56    15                  NaN
# 99999             43           45              45    33                  NaN
#
# ...

# %%
d.head()
# Out:
#    Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0             54           22              70    21                19.52
# 1             12           20              40   104                19.49
# 2             34           26              35    62                19.47
# 3              7           44              44    93                19.54
# 4             50           38              23    92                19.61
#
#    Wind speed (Km/h)  Air humidity (%)  Wind gust (Km/h)  Pressure (KPa)  \
# 0               2.13             55.04              6.30          101.50
# 1               2.01             55.17             10.46          101.50
# 2               1.90             55.30             14.63          101.51
# 3               2.28             54.20             16.08          101.51
# 4               2.66             53.09             17.52          101.51
#
#          ph    rainfall     N     P     K Status
# ...

# %%
d.tail()
# Out:
#        Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 99995             74            3              29    83                  NaN
# 99996             58           10              46    82                  NaN
# 99997              4           35              39    17                  NaN
# 99998             83           36              56    15                  NaN
# 99999             43           45              45    33                  NaN
#
#        Wind speed (Km/h)  Air humidity (%)  Wind gust (Km/h)  Pressure (KPa)  \
# 99995                NaN               NaN               NaN             NaN
# 99996                NaN               NaN               NaN             NaN
# 99997                NaN               NaN               NaN             NaN
# 99998                NaN               NaN               NaN             NaN
# 99999                NaN               NaN               NaN             NaN
#
#        ph  rainfall   N   P   K Status
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Soil Moisture        100000 non-null  int64
#  1   Temperature          100000 non-null  int64
#  2    Soil Humidity       100000 non-null  int64
#  3   Time                 100000 non-null  int64
#  4   Air temperature (C)  23995 non-null   float64
#  5   Wind speed (Km/h)    23995 non-null   float64
#  6   Air humidity (%)     23995 non-null   float64
#  7   Wind gust (Km/h)     23995 non-null   float64
#  8   Pressure (KPa)       23995 non-null   float64
#  9   ph                   2200 non-null    float64
#  10  rainfall             2200 non-null    float64
#  11  N                    2200 non-null    float64
#  12  P                    2200 non-null    float64
#  13  K                    2200 non-null    float64
# ...

# %%
d.index
# Out:
# RangeIndex(start=0, stop=100000, step=1)

# %%
d.columns
# Out:
# Index(['Soil Moisture', 'Temperature', ' Soil Humidity', 'Time',
#        'Air temperature (C)', 'Wind speed (Km/h)', 'Air humidity (%)',
#        'Wind gust (Km/h)', 'Pressure (KPa)', 'ph', 'rainfall', 'N', 'P', 'K',
#        'Status'],
#       dtype='object')

# %%
#How to changes the columns names
new={'rainfall':'Rainfall' }
new
# Out:
# {'rainfall': 'Rainfall'}

# %%
d.rename(columns=new,inplace=True)
d.head()
# Out:
#    Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0             54           22              70    21                19.52
# 1             12           20              40   104                19.49
# 2             34           26              35    62                19.47
# 3              7           44              44    93                19.54
# 4             50           38              23    92                19.61
#
#    Wind speed (Km/h)  Air humidity (%)  Wind gust (Km/h)  Pressure (KPa)  \
# 0               2.13             55.04              6.30          101.50
# 1               2.01             55.17             10.46          101.50
# 2               1.90             55.30             14.63          101.51
# 3               2.28             54.20             16.08          101.51
# 4               2.66             53.09             17.52          101.51
#
#          ph    Rainfall     N     P     K Status
# ...

# %%
d.iloc[15]
# Out:
# Soil Moisture                  39
# Temperature                    22
#  Soil Humidity                 48
# Time                           80
# Air temperature (C)         20.41
# Wind speed (Km/h)             3.9
# Air humidity (%)            41.71
# Wind gust (Km/h)            18.18
# Pressure (KPa)             101.48
# ph                       7.042299
# Rainfall               231.086335
# N                            60.0
# P                            48.0
# K                            39.0
# Status                         ON
# Name: 15, dtype: object

# %%
d[['Temperature','Air temperature (C)','Rainfall']]
# Out:
#        Temperature  Air temperature (C)    Rainfall
# 0               22                19.52  202.935536
# 1               20                19.49  226.655537
# 2               26                19.47  263.964248
# 3               44                19.54  242.864034
# 4               38                19.61  262.717340
# ...            ...                  ...         ...
# 99995            3                  NaN         NaN
# 99996           10                  NaN         NaN
# 99997           35                  NaN         NaN
# 99998           36                  NaN         NaN
# 99999           45                  NaN         NaN
#
# [100000 rows x 3 columns]

# %%
import numpy as np
plant=np.random.uniform(low=0,high=10,size=len(d['Time']))
plant=np.around(plant,decimals=2)
print(plant)
# Out:
# [1.3  1.75 3.68 ... 5.85 8.95 1.22]

# %%
#adding the 'cars' columns as a new column
d['plant']=plant
d
# Out:
#        Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0                 54           22              70    21                19.52
# 1                 12           20              40   104                19.49
# 2                 34           26              35    62                19.47
# 3                  7           44              44    93                19.54
# 4                 50           38              23    92                19.61
# ...              ...          ...             ...   ...                  ...
# 99995             74            3              29    83                  NaN
# 99996             58           10              46    82                  NaN
# 99997              4           35              39    17                  NaN
# 99998             83           36              56    15                  NaN
# 99999             43           45              45    33                  NaN
#
# ...

# %%
d['Pressure (KPa)'].min()
# Out:
# 100.5

# %%
d['Pressure (KPa)'].max()
# Out:
# 101.86

# %%
#get the missing null values- nan not a number
d.isnull()
# Out:
#        Soil Moisture  Temperature   Soil Humidity   Time  Air temperature (C)  \
# 0              False        False           False  False                False
# 1              False        False           False  False                False
# 2              False        False           False  False                False
# 3              False        False           False  False                False
# 4              False        False           False  False                False
# ...              ...          ...             ...    ...                  ...
# 99995          False        False           False  False                 True
# 99996          False        False           False  False                 True
# 99997          False        False           False  False                 True
# 99998          False        False           False  False                 True
# 99999          False        False           False  False                 True
#
# ...

# %%
d[d.isnull().any(axis=1)]
# Out:
#        Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 2200               1           31              20   102                31.41
# 2201              73            0              38   106                31.62
# 2202              84           35              54    28                31.83
# 2203              13           29              46    61                31.72
# 2204              75           23              67    56                31.62
# ...              ...          ...             ...   ...                  ...
# 99995             74            3              29    83                  NaN
# 99996             58           10              46    82                  NaN
# 99997              4           35              39    17                  NaN
# 99998             83           36              56    15                  NaN
# 99999             43           45              45    33                  NaN
#
# ...

# %%
#Drop items which have missing values in any of the columns
d.dropna()
# Out:
#       Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0                54           22              70    21                19.52
# 1                12           20              40   104                19.49
# 2                34           26              35    62                19.47
# 3                 7           44              44    93                19.54
# 4                50           38              23    92                19.61
# ...             ...          ...             ...   ...                  ...
# 2195             90           32              28    68                31.44
# 2196             41           21              48    42                31.47
# 2197             24           37              44    78                31.48
# 2198             10           15              22    62                31.48
# 2199             70           21              69    55                31.44
#
# ...

# %%
d.replace({'Time':{104:100,92:85}})
# Out:
#        Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0                 54           22              70    21                19.52
# 1                 12           20              40   100                19.49
# 2                 34           26              35    62                19.47
# 3                  7           44              44    93                19.54
# 4                 50           38              23    85                19.61
# ...              ...          ...             ...   ...                  ...
# 99995             74            3              29    83                  NaN
# 99996             58           10              46    82                  NaN
# 99997              4           35              39    17                  NaN
# 99998             83           36              56    15                  NaN
# 99999             43           45              45    33                  NaN
#
# ...

# %%
#how to delete the unnamed 13 column?
del d['N']   #artifical named most not be removed.
d.head()
# Out:
#    Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0             54           22              70    21                19.52
# 1             12           20              40   104                19.49
# 2             34           26              35    62                19.47
# 3              7           44              44    93                19.54
# 4             50           38              23    92                19.61
#
#    Wind speed (Km/h)  Air humidity (%)  Wind gust (Km/h)  Pressure (KPa)  \
# 0               2.13             55.04              6.30          101.50
# 1               2.01             55.17             10.46          101.50
# 2               1.90             55.30             14.63          101.51
# 3               2.28             54.20             16.08          101.51
# 4               2.66             53.09             17.52          101.51
#
#          ph    Rainfall     P     K Status  plant
# ...

# %%
# get max,min and mean of the 'cars' using agg()
d['plant'].agg(['max','min','mean'])
# Out:
# max     10.000000
# min      0.000000
# mean     5.002735
# Name: plant, dtype: float64

# %%
d[d['plant']==0].count()
# Out:
# Soil Moisture          47
# Temperature            47
#  Soil Humidity         47
# Time                   47
# Air temperature (C)    18
# Wind speed (Km/h)      18
# Air humidity (%)       18
# Wind gust (Km/h)       18
# Pressure (KPa)         18
# ph                      2
# Rainfall                2
# P                       2
# K                       2
# Status                 47
# plant                  47
# dtype: int64

# %%
d['plant'].describe()
# Out:
# count    100000.000000
# mean          5.002735
# std           2.890905
# min           0.000000
# 25%           2.490000
# 50%           5.000000
# 75%           7.500000
# max          10.000000
# Name: plant, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
car=pd.read_csv('cars2.csv')
car
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %%
#Cleaning the dataset
car=pd.read_csv('cars2.csv')
car
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %%
#Cleaning the dataset - removing the(;) semi colon
car=pd.read_csv('Cars2.csv',sep=';',index_col=0)
car
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
import numpy as np
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 33.0,4,91,53,1795,17.4,76,3,honda civic to 31.0,4,119,82,2720,19.4,82,1,chevy s-10
# Empty DataFrame

# %%
import pandas as pd
#assuring 'df' is your DataFrame
if 'origin' in df.columns:
    plt.bar(df['origin'],200)
else:
    print("Column 'origin' not found in DataFrame.")
# Out:
# Column 'origin' not found in DataFrame.

# %%
car['origin'].value_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 car['origin'].value_counts
#
# ...

# %%
plt.bar(car['origin'],200) # all values are same values.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 plt.bar(car['origin'],200)
#
# ...

# %%
car['model'].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'model'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 car['model'].hist()
#
# ...

# %%
car['cylinders'].hist() #histogram plot

# %%
plt.style.use('ggplot')
car['mpg'].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mpg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 2
#       1 plt.style.use('ggplot')
# ----> 2 car['mpg'].hist()
#
# ...

# %%
plt.style.use('fivethirtyeight')
car['cylinders'].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cylinders'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 2
#       1 plt.style.use('fivethirtyeight')
# ----> 2 car['cylinders'].hist()
#
# ...

# %%
plt.style.use('dark_background')
car['mpg'].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mpg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 2
#       1 plt.style.use('dark_background')
# ----> 2 car['mpg'].hist()
#
# ...

# %%
car.plot.area()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 car.plot.area()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1603, in PlotAccessor.area(self, x, y, stacked, **kwargs)
#    1526 def area(
#    1527     self,
#    1528     x: Hashable | None = None,
#    (...)
#    1531     **kwargs,
#    1532 ) -> PlotAccessor:
#    1533     """
#    1534     Draw a stacked area plot.
#    1535
#    (...)
#    1601         >>> ax = df.plot.area(x='day')
#    1602     """
# -> 1603     return self(kind="area", x=x, y=y, stacked=stacked, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
plt.style.use('ggplot')
car[['displacement','weight','origin']].plot.area()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 2
#       1 plt.style.use('ggplot')
# ----> 2 car[['displacement','weight','origin']].plot.area()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
import pandas as pd
d=pd.read_csv('TARP.csv')
d
# Out:
#        Soil Moisture  Temperature   Soil Humidity  Time  Air temperature (C)  \
# 0                 54           22              70    21                19.52
# 1                 12           20              40   104                19.49
# 2                 34           26              35    62                19.47
# 3                  7           44              44    93                19.54
# 4                 50           38              23    92                19.61
# ...              ...          ...             ...   ...                  ...
# 99995             74            3              29    83                  NaN
# 99996             58           10              46    82                  NaN
# 99997              4           35              39    17                  NaN
# 99998             83           36              56    15                  NaN
# 99999             43           45              45    33                  NaN
#
# ...
