# %%
import seaborn as sns
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
#  # Categorical plots: This plot deal with categorical variables and how they can be visualized.

# %%
# import the seaborn library
import seaborn as sns
#import done to avoid warnings
from warnings import filterwarnings
#READING the dataset
df=sns.load_dataset('tips')
#first five entries if the dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # BARPLOT:-
#         to use this plot we choose a categorical column for the x axis and a numerical column for the y axis and we see that
# it creates a plot taking a means per categorical column.

# %%
#Syntax:
# barplot([x,y,hue,data,order,,hue_order,..])
#set the background style of the plot
sns.set_style('darkgrid')
#plot the graph using the default estimator mean
sns.barplot(x='sex',y='total_bill',data=df,palette='plasma')
#or
import numpy as np
#change the estimator from means to standard devistion
sns.barplot(x='sex',y='total_bill',data=df, palette='plasma',estimator=np.std)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11452\613225883.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex',y='total_bill',data=df,palette='plasma')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11452\613225883.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex',y='total_bill',data=df, palette='plasma',estimator=np.std)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # Countplot:-
#    #A countplot basically counts the categories and return a count of their occurrences.it is one of the most simple plots
# #provided by the seaborn library.
# #syntax: Countplot([x,y,hue,data,order,..])
# #sns.countplot(x='sex',data=df)

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Vilolinplot
#  it is similar to the boxplot except that it provides a higher,more advanced visuliation and uses the kernel density
# estimation to given a better description about the data distrubution.

# %%
import seaborn as sns
df=sns.load_dataset('tips')
sns.violinplot(x='day',y='total_bill',data=df,hue='sex',split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Stripplot:
   # It basically create a scatter plot based on the category.
sns.stripplot(x='day',y='total_bill',data=df,jitter=True,hue='smoker',dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Swarmplot:-
#   It is very similar to the stripplot except the fact that the points are adjusted so that they do not overlap. Some peoople alos
# like combining the idea of a violin plot and a stripplot to form ths plot.
#   One drawback to using swarmplot is that sometimes they dont scale well to reallu large numbers and takes a lot of
# computation to arrange them.so in case we want to arrange then. So in case we want to visualizw a swarmplot properly we can
# plot in on top of violinplot.

# %%
sns.swarmplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill',data=df)
sns.swarmplot(x='day',y='total_bill',data=df,color='yellow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.factorplot(x='day',y='total_bill',data=df,kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 sns.factorplot(x='day',y='total_bill',data=df,kind='bar')
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %% [markdown]
# # Distribution plot:
#   This plot us used for examining univariate and bivariate distributions.
#       4 types of distributions seaborn they are,
#        joinplot,distplot,pairplot,rugplot.
# # Distplot:
#       it is used bascially for univariant set of obseations and visualizes it through a histogram
# syntax:- distplot(a[,bins,hist,kde,rug,fit,..])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('whitegrid')
sns.distplot(df['total_bill'], kde = False, color='red',bins=30) #-->it will be length of bar size.
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11452\224453078.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'], kde = False, color='red',bins=30) #-->it will be length of bar size.
# <Axes: xlabel='total_bill'>

# %% [markdown]
# # join plot:-
#         its used to draw a plot of two varaibles with bivariate and univaraite graphs. its basically combines two differnt plots.
#        # Syntax: jointplot(x,y,[,data,kind,stat_fun,..])

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde')
#KDE shows the density where the points match up the most

# %% [markdown]
# # Pairplot In Seaborn:
#         In Seaborn, pairplot is a powerful function that allows you to visualize the relationships between multiple variables
#         in a dataset, typically through a grid of scatterplots and histograms or kernel density estimates (KDE) on the diagonal.
#         It can help you explore the pairwise correlations between continuous variables and identify patterns such as clusters,
#         outliers, or linear relationships.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Load a sample dataset (e.g., Iris dataset)
df = sns.load_dataset('iris')
# Create a pairplot of the entire dataset
sns.pairplot(df)
plt.show()

# %%
# Create a pairplot with coloring by species and regression lines
sns.pairplot(df, hue='species', kind='reg', height=2.5)
plt.show()

# %%
# Create a pairplot with KDE on the diagonal and scatter on off-diagonal
sns.pairplot(df, diag_kind='kde', height=2.5)
plt.show()

# %%
# Create a pairplot with different markers for each species
sns.pairplot(df, hue='species', markers=["o", "s", "D"], height=2.5)
plt.show()

# %% [markdown]
# # Regression plots:

# %% [markdown]
#  The regression plots in seaborn are primarily intended to add a visual guide that helps to emphasize patterns in dataser
# during exploratory data analyses.
#  The regression plots in seabor can be easily implemented with the help of the implot() funtion. implot() can be
# understoof as a function that basically creates a linear model plot.

# %%
sns.set_style('whitegrid')
sns.implot(x='total_bill',y='tip',data=dataset)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[195], line 2
#       1 sns.set_style('whitegrid')
# ----> 2 sns.implot(x='total_bill',y='tip',data=dataset)
#
# AttributeError: module 'seaborn' has no attribute 'implot'

# %%
sns.set_style('whitegrid')
sns.implot(x='total_bill',y='tip',data=dataset,hue='sex',markers=['o','v'])

# %%
sns.set_style('whitegrid')
sns.implot(x='total_bill',y='tip',data=dataset,hue='sex',markers=['o','v'],scatter_kws={'s':100},palette='plasms')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[157], line 2
#       1 sns.set_style('whitegrid')
# ----> 2 sns.implot(x='total_bill',y='tip',data=dataset,hue='sex',markers=['o','v'],scatter_kws={'s':100},palette='plasms')
#
# AttributeError: module 'seaborn' has no attribute 'implot'

# %% [markdown]
# # Matrix plots:-

# %% [markdown]
#  A matrix plot is an array of scatter plots.some of them include count,scatter,pair,regression,matrix,and much more plots will be used.
# example of HEATMAP.

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
% matplotlib inline
#load the tips dataset
dataset=sns.load_dataset('tips')
#first five entries of the tips dataset
dataset.head()
#correalation between the different parameters
tc=dataset.corr()
#plot a heatmap of the correlated data
sns.heatmap(tc)
# Out:
# UsageError: Line magic function `%` not found.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# If you're using a Jupyter notebook, use the magic function %matplotlib inline to display plots inline
# %matplotlib inline  

# Load the tips dataset
dataset = sns.load_dataset('tips')

# Show the first five entries of the dataset
print(dataset.head())

numeric_dataset=dataset.select_dtypes(include=['float64','int64'])


# Compute the correlation between the different parameters
tc =numeric_dataset.corr()  # correlation asign numberic value only.

# Plot a heatmap of the correlation data
sns.heatmap(tc, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)

# Show the plot
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# If you're using a Jupyter notebook, use the magic function %matplotlib inline to display plots inline
# %matplotlib inline  
# Load the tips dataset
dataset = sns.load_dataset('tips')
# Show the first five entries of the dataset
print(dataset.head())

numeric_dataset=dataset.select_dtypes(include=['float64','int64'])

# Compute the correlation between the different parameters
tc =numeric_dataset.corr()  # correlation asign numberic value only..

# Plot a heatmap of the correlation data
sns.heatmap(tc, annot=True, cmap='plasma', linecolor='black', linewidths=5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <Axes: >

# %% [markdown]
# # Cluster maps:-
#   Cluster maps use hierarchical clustering.it performs the clustering based on the similarity of the woes and columns.

# %%
#import the necessary libraries:
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# If you're using a Jupyter notebook, use the magic function %matplotlib inline to display plots inline
# %matplotlib inline  
#load the flights dataset:
fd=sns.load_dataset('flights')
#make a dataframe of the data
df=pd.pivot_table(values='passengers',index='month',columns='year',data=fd)
#first five entries of the dataset
df.head()
#make a clustermap from the  dataset
sns.clustermap(df,cmap='plasma')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10204\3115221786.py:10: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df=pd.pivot_table(values='passengers',index='month',columns='year',data=fd)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# If you're using a Jupyter notebook, use the magic function %matplotlib inline to display plots inline
# %matplotlib inline  

fd=sns.load_dataset('flights')
df=pd.pivot_table(values='passengers',index='month',columns='year',data=fd)
df.head()
sns.clustermap(df,cmap='plasma',standard_scale=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10204\4131055959.py:8: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df=pd.pivot_table(values='passengers',index='month',columns='year',data=fd)

# %% [markdown]
# # Multi-plot grids: it is useful approach to drawn multiple instances of the same plot on different subsets of the dataset.
